# %% [markdown]
# **Subhav batra**
# **102003751**

# %%
import pandas as pd
df = pd.DataFrame()

#Importing the dataset
customers=pd.read_csv('AWCustomers.csv')

#displayng the data
display(customers.head())

#Testing to check if the code is correct
print("No.of Customers",len(customers))
# Out:
#    CustomerID Title FirstName MiddleName  LastName Suffix  \
# 0       21173   NaN      Chad          C      Yuan    NaN
# 1       13249   NaN      Ryan        NaN     Perry    NaN
# 2       29350   NaN     Julia        NaN  Thompson    NaN
# 3       13503   NaN  Theodore        NaN     Gomez    NaN
# 4       22803   NaN  Marshall          J      Shan    NaN
#
#              AddressLine1 AddressLine2         City    StateProvinceName  ...  \
# 0      7090 C. Mount Hood          NaN   Wollongong      New South Wales  ...
# 1     3651 Willow Lake Rd          NaN      Shawnee     British Columbia  ...
# 2  1774 Tice Valley Blvd.          NaN  West Covina           California  ...
# 3         2103 Baldwin Dr          NaN    Liverpool              England  ...
# 4         Am Gallberg 234          NaN        Werne  Nordrhein-Westfalen  ...
#
#          Education      Occupation Gender MaritalStatus HomeOwnerFlag  \
# 0        Bachelors        Clerical      M             M           1.0
# 1  Partial College        Clerical      M             M           1.0
# 2        Bachelors        Clerical      F             S           0.0
# 3  Partial College  Skilled Manual      M             M           1.0
# 4  Partial College  Skilled Manual      M             S           1.0
#
#   NumberCarsOwned NumberChildrenAtHome TotalChildren  YearlyIncome  \
# 0             3.0                  0.0           1.0       81916.0
# 1             2.0                  1.0           2.0       81076.0
# 2             3.0                  0.0           0.0       86387.0
# 3             2.0                  1.0           2.0       61481.0
# 4             1.0                  0.0           0.0       51804.0
#
#    LastUpdated
# 0   2017-03-06
# 1   2017-03-06
# 2   2017-03-06
# 3   2017-03-06
# 4   2017-03-06
#
# [5 rows x 24 columns]
# No.of Customers 11788

# %%
customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11788 entries, 0 to 11787
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   CustomerID            11788 non-null  int64
#  1   Title                 65 non-null     object
#  2   FirstName             11788 non-null  object
#  3   MiddleName            6831 non-null   object
#  4   LastName              11788 non-null  object
#  5   Suffix                2 non-null      object
#  6   AddressLine1          11788 non-null  object
#  7   AddressLine2          211 non-null    object
#  8   City                  11788 non-null  object
#  9   StateProvinceName     11788 non-null  object
#  10  CountryRegionName     11788 non-null  object
#  11  PostalCode            11788 non-null  object
#  12  PhoneNumber           11788 non-null  object
#  13  BirthDate             11788 non-null  object
#  14  Education             11788 non-null  object
#  15  Occupation            11787 non-null  object
#  16  Gender                11787 non-null  object
#  17  MaritalStatus         11787 non-null  object
#  18  HomeOwnerFlag         11787 non-null  float64
#  19  NumberCarsOwned       11787 non-null  float64
#  20  NumberChildrenAtHome  11787 non-null  float64
#  21  TotalChildren         11787 non-null  float64
#  22  YearlyIncome          11787 non-null  float64
#  23  LastUpdated           11787 non-null  object
# dtypes: float64(5), int64(1), object(18)
# memory usage: 2.2+ MB

# %%
#columns - title, suffix and address line contain large number of NULL values and hence are removed
important_cols=['AddressLine1','AddressLine2','City','StateProvinceName','CountryRegionName','PostalCode',
                'BirthDate','Education','Occupation','Gender','MaritalStatus','HomeOwnerFlag',
               'NumberCarsOwned','NumberChildrenAtHome','TotalChildren','YearlyIncome']

# %%
df = customers[important_cols]

# %%
df.head()
# Out:
#              AddressLine1 AddressLine2         City    StateProvinceName  \
# 0      7090 C. Mount Hood          NaN   Wollongong      New South Wales
# 1     3651 Willow Lake Rd          NaN      Shawnee     British Columbia
# 2  1774 Tice Valley Blvd.          NaN  West Covina           California
# 3         2103 Baldwin Dr          NaN    Liverpool              England
# 4         Am Gallberg 234          NaN        Werne  Nordrhein-Westfalen
#
#   CountryRegionName PostalCode   BirthDate        Education      Occupation  \
# 0         Australia       2500  1987-11-13        Bachelors        Clerical
# 1            Canada    V9B 2C3  1972-07-21  Partial College        Clerical
# 2     United States      91791  1985-11-09        Bachelors        Clerical
# 3    United Kingdom     L4 4HB  1977-10-18  Partial College  Skilled Manual
# 4           Germany      59368  1975-02-05  Partial College  Skilled Manual
#
#   Gender MaritalStatus  HomeOwnerFlag  NumberCarsOwned  NumberChildrenAtHome  \
# 0      M             M              1                3                     0
# 1      M             M              1                2                     1
# 2      F             S              0                3                     0
# 3      M             M              1                2                     1
# 4      M             S              1                1                     0
#
#    TotalChildren  YearlyIncome
# 0              1         81916
# 1              2         81076
# 2              0         86387
# 3              2         61481
# 4              0         51804

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18361 entries, 0 to 18360
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   AddressLine1          18361 non-null  object
#  1   AddressLine2          311 non-null    object
#  2   City                  18361 non-null  object
#  3   StateProvinceName     18361 non-null  object
#  4   CountryRegionName     18361 non-null  object
#  5   PostalCode            18361 non-null  object
#  6   BirthDate             18361 non-null  object
#  7   Education             18361 non-null  object
#  8   Occupation            18361 non-null  object
#  9   Gender                18361 non-null  object
#  10  MaritalStatus         18361 non-null  object
#  11  HomeOwnerFlag         18361 non-null  int64
#  12  NumberCarsOwned       18361 non-null  int64
#  13  NumberChildrenAtHome  18361 non-null  int64
#  14  TotalChildren         18361 non-null  int64
#  15  YearlyIncome          18361 non-null  int64
# dtypes: int64(5), object(11)
# memory usage: 2.2+ MB

# %%
print(
    "Number of unique address",len(df['AddressLine1'].unique()),'\n',
    "Number of unique city",len(df['City'].unique()),'\n',
    "Number of unique postal code",len(df['PostalCode'].unique()),'\n',
    "Number of unique states",len(df['StateProvinceName'].unique()),'\n',
    "Number of unique country",len(df['CountryRegionName'].unique())
)
# Out:
# Number of unique address 12742
#  Number of unique city 269
#  Number of unique postal code 323
#  Number of unique states 54
#  Number of unique country 6

# %%
def preprocess_address(df):
    df.drop(columns=['AddressLine1','AddressLine2','City','StateProvinceName','PostalCode'],axis=1,inplace=True)
    ohe_countries=pd.get_dummies(df['CountryRegionName'],drop_first=True)
    df.drop(columns=['CountryRegionName'],axis=1,inplace=True)
    df=pd.concat([ohe_countries,df],axis=1)
    return df

# %%
df=preprocess_address(df)
df.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#    Canada  France  Germany  United Kingdom  United States   BirthDate  \
# 0       0       0        0               0              0  1987-11-13
# 1       1       0        0               0              0  1972-07-21
# 2       0       0        0               0              1  1985-11-09
# 3       0       0        0               1              0  1977-10-18
# 4       0       0        1               0              0  1975-02-05
#
#          Education      Occupation Gender MaritalStatus  HomeOwnerFlag  \
# 0        Bachelors        Clerical      M             M              1
# 1  Partial College        Clerical      M             M              1
# 2        Bachelors        Clerical      F             S              0
# 3  Partial College  Skilled Manual      M             M              1
# 4  Partial College  Skilled Manual      M             S              1
#
#    NumberCarsOwned  NumberChildrenAtHome  TotalChildren  YearlyIncome
# 0                3                     0              1         81916
# 1                2                     1              2         81076
# 2                3                     0              0         86387
# 3                2                     1              2         61481
# 4                1                     0              0         51804

# %%
df['BirthDate']= pd.to_datetime(df['BirthDate'])

import datetime
CURRENT_TIME = datetime.datetime.now()
def get_age(birth_date,today=CURRENT_TIME):
    y=today-birth_date
    return y.days//365

df['Age']=df['BirthDate'].apply(lambda x: get_age(x))
df.drop(['BirthDate'],axis=1,inplace=True)
df.head()
# Out:
#    Canada  France  Germany  United Kingdom  United States        Education  \
# 0       0       0        0               0              0        Bachelors
# 1       1       0        0               0              0  Partial College
# 2       0       0        0               0              1        Bachelors
# 3       0       0        0               1              0  Partial College
# 4       0       0        1               0              0  Partial College
#
#        Occupation Gender MaritalStatus  HomeOwnerFlag  NumberCarsOwned  \
# 0        Clerical      M             M              1                3
# 1        Clerical      M             M              1                2
# 2        Clerical      F             S              0                3
# 3  Skilled Manual      M             M              1                2
# 4  Skilled Manual      M             S              1                1
#
#    NumberChildrenAtHome  TotalChildren  YearlyIncome  Age
# 0                     0              1         81916   34
# 1                     1              2         81076   50
# 2                     0              0         86387   36
# 3                     1              2         61481   44
# 4                     0              0         51804   47

# %%
df['Education'].value_counts()
# Out:
# Bachelors              5325
# Partial College        5024
# High School            3274
# Graduate Degree        3163
# Partial High School    1575
# Name: Education, dtype: int64

# %%
df['Education']=df['Education'].map({'Partial High School':1,'High School':2,'Partial College':3,'Bachelors':4,'Graduate Degree':5})

# %%
df['Occupation']=df['Occupation'].map({'Manual':1,'Skilled Manual':2,'Clerical':3,'Management':4,'Professional':5})

# %%
df.head()
# Out:
#    Canada  France  Germany  United Kingdom  United States  Education  \
# 0       0       0        0               0              0          4
# 1       1       0        0               0              0          3
# 2       0       0        0               0              1          4
# 3       0       0        0               1              0          3
# 4       0       0        1               0              0          3
#
#    Occupation Gender MaritalStatus  HomeOwnerFlag  NumberCarsOwned  \
# 0           3      M             M              1                3
# 1           3      M             M              1                2
# 2           3      F             S              0                3
# 3           2      M             M              1                2
# 4           2      M             S              1                1
#
#    NumberChildrenAtHome  TotalChildren  YearlyIncome  Age
# 0                     0              1         81916   34
# 1                     1              2         81076   50
# 2                     0              0         86387   36
# 3                     1              2         61481   44
# 4                     0              0         51804   47

# %%
def handle_cardinal_cols(df):
    df['Male']=df['Gender'].map({'M':1,'F':0})
    df.drop(['Gender'],axis=1,inplace=True)
    df['MaritalStatus']=df['MaritalStatus'].map({'M':1,'S':0})
    
    return df

# %%
df=handle_cardinal_cols(df)
df.head()
# Out:
#    Canada  France  Germany  United Kingdom  United States  Education  \
# 0       0       0        0               0              0          4
# 1       1       0        0               0              0          3
# 2       0       0        0               0              1          4
# 3       0       0        0               1              0          3
# 4       0       0        1               0              0          3
#
#    Occupation  MaritalStatus  HomeOwnerFlag  NumberCarsOwned  \
# 0           3              1              1                3
# 1           3              1              1                2
# 2           3              0              0                3
# 3           2              1              1                2
# 4           2              0              1                1
#
#    NumberChildrenAtHome  TotalChildren  YearlyIncome  Age  Male
# 0                     0              1         81916   34     1
# 1                     1              2         81076   50     1
# 2                     0              0         86387   36     0
# 3                     1              2         61481   44     1
# 4                     0              0         51804   47     1

# %%
df['Occupation'].value_counts()
# Out:
# 2    6059
# 3    4464
# 1    3377
# 4    2858
# 5    1603
# Name: Occupation, dtype: int64

# %%
df.isnull().sum()
# Out:
# Canada                  0
# France                  0
# Germany                 0
# United Kingdom          0
# United States           0
# Education               0
# Occupation              0
# MaritalStatus           0
# HomeOwnerFlag           0
# NumberCarsOwned         0
# NumberChildrenAtHome    0
# TotalChildren           0
# YearlyIncome            0
# Age                     0
# Male                    0
# dtype: int64

# %%
from sklearn.preprocessing import MinMaxScaler
def scaleDown(df):
    scaler=MinMaxScaler()
    scaled=scaler.fit_transform(df[['YearlyIncome','Age']])
    df['YearlyIncome_scaled']=scaled[:,0]
    df['Age_scaled']=scaled[:,1]
    df.drop(['YearlyIncome','Age'],axis=1,inplace=True)
    return df

# %%
df=scaleDown(df)

# %%
df.head()
# Out:
#    Canada  France  Germany  United Kingdom  United States  Education  \
# 0       0       0        0               0              0          4
# 1       1       0        0               0              0          3
# 2       0       0        0               0              1          4
# 3       0       0        0               1              0          3
# 4       0       0        1               0              0          3
#
#    Occupation  MaritalStatus  HomeOwnerFlag  NumberCarsOwned  \
# 0           3              1              1                3
# 1           3              1              1                2
# 2           3              0              0                3
# 3           2              1              1                2
# 4           2              0              1                1
#
#    NumberChildrenAtHome  TotalChildren  Male  YearlyIncome_scaled  Age_scaled
# 0                     0              1     1             0.496842    0.183099
# 1                     1              2     1             0.489453    0.408451
# 2                     0              0     0             0.536172    0.211268
# 3                     1              2     1             0.317083    0.323944
# 4                     0              0     1             0.231958    0.366197

# %%
#Binarization (One Hot Encoding)
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()
df["Education"]=encoder.fit_transform(df['Education'])
df["Occupation"]=encoder.fit_transform(df['Occupation'])

# %%
df.head()
# Out:
#    Canada  France  Germany  United Kingdom  United States  Education  \
# 0       0       0        0               0              0          3
# 1       1       0        0               0              0          2
# 2       0       0        0               0              1          3
# 3       0       0        0               1              0          2
# 4       0       0        1               0              0          2
#
#    Occupation  MaritalStatus  HomeOwnerFlag  NumberCarsOwned  \
# 0           2              1              1                3
# 1           2              1              1                2
# 2           2              0              0                3
# 3           1              1              1                2
# 4           1              0              1                1
#
#    NumberChildrenAtHome  TotalChildren  Male  YearlyIncome_scaled  Age_scaled
# 0                     0              1     1             0.496842    0.183099
# 1                     1              2     1             0.489453    0.408451
# 2                     0              0     0             0.536172    0.211268
# 3                     1              2     1             0.317083    0.323944
# 4                     0              0     1             0.231958    0.366197

# %%
from scipy.spatial import distance

# %%
distance.cosine(df['Education'].values,df['YearlyIncome_scaled'].values)
# Out:
# 0.13839499439016045

# %%
distance.jaccard(df['Education'].values,df['YearlyIncome_scaled'].values)
# Out:
# 1.0

# %%
from scipy.stats import pearsonr
pearsonr(df['Education'].values,df['YearlyIncome_scaled'].values)[0]
# Out:
# 0.46766483550548943
