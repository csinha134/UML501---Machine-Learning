# %%
import pandas as pd
import numpy as np

# %%
file=pd.read_csv("/Users/chayansinha/Desktop/archive/AWCustomers.csv")

# %%
file.head()
# Out:
#    CustomerID Title FirstName MiddleName  LastName Suffix  \
# 0       21173   NaN      Chad          C      Yuan    NaN
# 1       13249   NaN      Ryan        NaN     Perry    NaN
# 2       29350   NaN     Julia        NaN  Thompson    NaN
# 3       13503   NaN  Theodore        NaN     Gomez    NaN
# 4       22803   NaN  Marshall          J      Shan    NaN
#
#              AddressLine1 AddressLine2         City    StateProvinceName  ...  \
# 0      7090 C. Mount Hood          NaN   Wollongong      New South Wales  ...
# 1     3651 Willow Lake Rd          NaN      Shawnee     British Columbia  ...
# 2  1774 Tice Valley Blvd.          NaN  West Covina           California  ...
# 3         2103 Baldwin Dr          NaN    Liverpool              England  ...
# 4         Am Gallberg 234          NaN        Werne  Nordrhein-Westfalen  ...
#
#          Education      Occupation Gender MaritalStatus HomeOwnerFlag  \
# 0        Bachelors        Clerical      M             M             1
# ...

# %%
a=file.iloc[0]
print(a)
# Out:
# CustomerID                            21173
# Title                                   NaN
# FirstName                              Chad
# MiddleName                                C
# LastName                               Yuan
# Suffix                                  NaN
# AddressLine1             7090 C. Mount Hood
# AddressLine2                            NaN
# City                             Wollongong
# StateProvinceName           New South Wales
# CountryRegionName                 Australia
# PostalCode                             2500
# PhoneNumber             1 (11) 500 555-0115
# BirthDate                        1987-11-13
# Education                         Bachelors
# Occupation                         Clerical
# Gender                                    M
# MaritalStatus                             M
# HomeOwnerFlag                             1
# NumberCarsOwned                           3
# NumberChildrenAtHome                      0
# ...

# %%
a=file.iloc[-1]
print(a)
# Out:
# CustomerID                            16676
# Title                                   NaN
# FirstName                            Amanda
# MiddleName                              NaN
# LastName                              Perry
# Suffix                                  NaN
# AddressLine1            7870 Orangewood Dr.
# AddressLine2                            NaN
# City                              Grossmont
# StateProvinceName                California
# CountryRegionName             United States
# PostalCode                            91941
# PhoneNumber                    553-555-0122
# BirthDate                        1986-03-26
# Education                   Graduate Degree
# Occupation                     Professional
# Gender                                    F
# MaritalStatus                             M
# HomeOwnerFlag                             1
# NumberCarsOwned                           2
# NumberChildrenAtHome                      0
# ...

# %%
a=file.iloc[0,1]
print(a)
# Out:
# nan

# %%
a=file.iloc[0:20]
print(a)
# Out:
#     CustomerID Title FirstName MiddleName       LastName Suffix  \
# 0        21173   NaN      Chad          C           Yuan    NaN
# 1        13249   NaN      Ryan        NaN          Perry    NaN
# 2        29350   NaN     Julia        NaN       Thompson    NaN
# 3        13503   NaN  Theodore        NaN          Gomez    NaN
# 4        22803   NaN  Marshall          J           Shan    NaN
# 5        22092   NaN    Andrea        NaN          Young    NaN
# 6        11229   NaN    Adrian          C        Stewart    NaN
# 7        24179   NaN     Robyn          R         Blanco    NaN
# 8        12127   NaN     Grace        NaN          Davis    NaN
# 9        19903   NaN    Marcus          N         Nelson    NaN
# 10       25924   NaN    Hannah        NaN       Robinson    NaN
# 11       23033   NaN      Alex          J         Turner    NaN
# 12       20029   NaN       Jan          M          Evans    NaN
# 13       22031   NaN     Jorge        NaN            Cai    NaN
# ...

# %%
a=file.iloc[:,0:2]
print(a)
# Out:
#        CustomerID Title
# 0           21173   NaN
# 1           13249   NaN
# 2           29350   NaN
# 3           13503   NaN
# 4           22803   NaN
# ...           ...   ...
# 18356       25414   NaN
# 18357       11459   NaN
# 18358       12160   NaN
# 18359       14353   NaN
# 18360       16676   NaN
#
# [18361 rows x 2 columns]

# %%
a=file.iloc[:,0:-1]
print(a)
# Out:
#        CustomerID Title FirstName MiddleName  LastName Suffix  \
# 0           21173   NaN      Chad          C      Yuan    NaN
# 1           13249   NaN      Ryan        NaN     Perry    NaN
# 2           29350   NaN     Julia        NaN  Thompson    NaN
# 3           13503   NaN  Theodore        NaN     Gomez    NaN
# 4           22803   NaN  Marshall          J      Shan    NaN
# ...           ...   ...       ...        ...       ...    ...
# 18356       25414   NaN     Grace          C    Bailey    NaN
# 18357       11459   NaN     Tasha        NaN      Deng    NaN
# 18358       12160   NaN    Jaclyn        NaN     Zhang    NaN
# 18359       14353   NaN      Erin          I      Reed    NaN
# 18360       16676   NaN    Amanda        NaN     Perry    NaN
#
#                  AddressLine1 AddressLine2            City  \
# 0          7090 C. Mount Hood          NaN      Wollongong
# 1         3651 Willow Lake Rd          NaN         Shawnee
# ...

# %%
a=file.iloc[[1,3,5,6],[0,5,3,6]]
print(a)
# Out:
#    CustomerID Suffix MiddleName         AddressLine1
# 1       13249    NaN        NaN  3651 Willow Lake Rd
# 3       13503    NaN        NaN      2103 Baldwin Dr
# 5       22092    NaN        NaN    9384 Ashmount Way
# 6       11229    NaN          C        6898 Shaw Rd.

# %%
print('Shape : ',file.shape)
file.head()
# Out:
# Shape :  (18361, 24)
#    CustomerID Title FirstName MiddleName  LastName Suffix  \
# 0       21173   NaN      Chad          C      Yuan    NaN
# 1       13249   NaN      Ryan        NaN     Perry    NaN
# 2       29350   NaN     Julia        NaN  Thompson    NaN
# 3       13503   NaN  Theodore        NaN     Gomez    NaN
# 4       22803   NaN  Marshall          J      Shan    NaN
#
#              AddressLine1 AddressLine2         City    StateProvinceName  ...  \
# 0      7090 C. Mount Hood          NaN   Wollongong      New South Wales  ...
# 1     3651 Willow Lake Rd          NaN      Shawnee     British Columbia  ...
# 2  1774 Tice Valley Blvd.          NaN  West Covina           California  ...
# 3         2103 Baldwin Dr          NaN    Liverpool              England  ...
# 4         Am Gallberg 234          NaN        Werne  Nordrhein-Westfalen  ...
#
#          Education      Occupation Gender MaritalStatus HomeOwnerFlag  \
# ...

# %%
file2=pd.read_csv("/Users/chayansinha/Desktop/archive/AWSales.csv")
file2.head()
# Out:
#    CustomerID  BikeBuyer  AvgMonthSpend
# 0       21173          1          50.97
# 1       13249          1          53.11
# 2       29350          1          54.08
# 3       13503          1          56.93
# 4       22803          1          55.41

# %%
file.head()
# Out:
#    CustomerID Title FirstName MiddleName  LastName Suffix  \
# 0       21173   NaN      Chad          C      Yuan    NaN
# 1       13249   NaN      Ryan        NaN     Perry    NaN
# 2       29350   NaN     Julia        NaN  Thompson    NaN
# 3       13503   NaN  Theodore        NaN     Gomez    NaN
# 4       22803   NaN  Marshall          J      Shan    NaN
#
#              AddressLine1 AddressLine2         City    StateProvinceName  ...  \
# 0      7090 C. Mount Hood          NaN   Wollongong      New South Wales  ...
# 1     3651 Willow Lake Rd          NaN      Shawnee     British Columbia  ...
# 2  1774 Tice Valley Blvd.          NaN  West Covina           California  ...
# 3         2103 Baldwin Dr          NaN    Liverpool              England  ...
# 4         Am Gallberg 234          NaN        Werne  Nordrhein-Westfalen  ...
#
#          Education      Occupation Gender MaritalStatus HomeOwnerFlag  \
# 0        Bachelors        Clerical      M             M             1
# ...

# %%
a=file.iloc[:,[0,2,8,22]]
print(a)
# Out:
#        CustomerID FirstName            City  YearlyIncome
# 0           21173      Chad      Wollongong         81916
# 1           13249      Ryan         Shawnee         81076
# 2           29350     Julia     West Covina         86387
# 3           13503  Theodore       Liverpool         61481
# 4           22803  Marshall           Werne         51804
# ...           ...       ...             ...           ...
# 18356       25414     Grace        Coronado         52953
# 18357       11459     Tasha  Port Macquarie         60992
# 18358       12160    Jaclyn       Beaverton         51859
# 18359       14353      Erin       Vancouver         87177
# 18360       16676    Amanda       Grossmont        136856
#
# [18361 rows x 4 columns]

# %%
file
# Out:
#        CustomerID Title FirstName MiddleName  LastName Suffix  \
# 0           21173   NaN      Chad          C      Yuan    NaN
# 1           13249   NaN      Ryan        NaN     Perry    NaN
# 2           29350   NaN     Julia        NaN  Thompson    NaN
# 3           13503   NaN  Theodore        NaN     Gomez    NaN
# 4           22803   NaN  Marshall          J      Shan    NaN
# ...           ...   ...       ...        ...       ...    ...
# 18356       25414   NaN     Grace          C    Bailey    NaN
# 18357       11459   NaN     Tasha        NaN      Deng    NaN
# 18358       12160   NaN    Jaclyn        NaN     Zhang    NaN
# 18359       14353   NaN      Erin          I      Reed    NaN
# 18360       16676   NaN    Amanda        NaN     Perry    NaN
#
#                  AddressLine1 AddressLine2            City  \
# 0          7090 C. Mount Hood          NaN      Wollongong
# 1         3651 Willow Lake Rd          NaN         Shawnee
# ...

# %%
a=file.groupby(['City'])['CustomerID'].count()
print(a)
# Out:
# City
# Ballard               67
# Baltimore              1
# Barstow                1
# Basingstoke Hants      2
# Baytown                1
#                     ...
# Woodburn              89
# Woodland Hills        96
# Woolston              30
# Yakima                96
# York                 115
# Name: CustomerID, Length: 269, dtype: int64
